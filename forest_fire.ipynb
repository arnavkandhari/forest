# %% [markdown]
# <a href="https://colab.research.google.com/github/arnavkandhari/forest/blob/main/forest_fire.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/arnavkandhari/forest ./data
# Out:
# Cloning into './data'...
# remote: Enumerating objects: 3818, done.
# remote: Counting objects: 100% (393/393), done.
# remote: Compressing objects: 100% (386/386), done.
# remote: Total 3818 (delta 7), reused 393 (delta 7), pack-reused 3425
# Receiving objects: 100% (3818/3818), 77.45 MiB | 29.83 MiB/s, done.
# Resolving deltas: 100% (11/11), done.

# %%
# !nvidia-smi
# Out:
# Sat Oct 14 09:57:38 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   44C    P8     9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 641.7/641.7 kB 6.8 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

# %%
# !yolo task=detect mode=train model=yolov8l.pt data=../content/data/data.yaml epochs=100 imgsz=640
# Out:
# ...
# 100% 83.7M/83.7M [00:01<00:00, 72.6MB/s]
# Ultralytics YOLOv8.0.198 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !zip -r /content/results.zip /content/runs/detect/train
from google.colab import files
files.download("/content/results.zip")
# Out:
#   adding: content/runs/detect/train/ (stored 0%)
#   adding: content/runs/detect/train/R_curve.png (deflated 13%)
#   adding: content/runs/detect/train/train_batch6750.jpg (deflated 8%)
#   adding: content/runs/detect/train/labels_correlogram.jpg (deflated 38%)
#   adding: content/runs/detect/train/weights/ (stored 0%)
#   adding: content/runs/detect/train/weights/last.pt (deflated 8%)
#   adding: content/runs/detect/train/weights/best.pt (deflated 8%)
#   adding: content/runs/detect/train/val_batch2_labels.jpg (deflated 7%)
#   adding: content/runs/detect/train/train_batch6752.jpg (deflated 8%)
#   adding: content/runs/detect/train/F1_curve.png (deflated 15%)
#   adding: content/runs/detect/train/val_batch2_pred.jpg (deflated 7%)
#   adding: content/runs/detect/train/results.png (deflated 8%)
#   adding: content/runs/detect/train/train_batch1.jpg (deflated 3%)
#   adding: content/runs/detect/train/train_batch0.jpg (deflated 2%)
# ...
